# %%
import os, sys
sys.path.append('../')
import patchsim as sim
import numpy as np
import matplotlib.pyplot as plt

# %%
os.chdir('../manual_tests/')

# %%
cfg = sim.read_config('cfg_test_det')
out = sim.run_disease_simulation(cfg,return_epi=True,write_epi=False).T

# %%
out
# Out:
# id  A  B  C
# 0   0  0  0
# 1   0  0  0
# 2   0  0  0
# 3   0  0  0
# 4   1  0  0
# .. .. .. ..
# 95  5  3  5
# 96  5  3  5
# 97  5  3  5
# 98  5  3  5
# 99  6  3  5
#
# [100 rows x 3 columns]

# %%
out.plot()
# Out:
# <Axes: >

# %%
plt.figure()
ax = plt.gca()
for i in range(30):
    cfg['RandomSeed'] = np.random.randint(1,10**6,1)
    out = sim.run_disease_simulation(cfg,return_epi=True,write_epi=False).T
    ax.set_prop_cycle(None)
    out.plot(ax=ax,alpha=0.2,legend=False)
